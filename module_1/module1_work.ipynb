# %%
import pandas as pd
df = pd.read_csv('data_sf.csv')
df.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Columns: 42 entries, Unnamed: 0 to GKReflexes
# dtypes: int64(38), object(4)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df.describe())
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
df['Age'].mean()
# Out:
# 24.795378770256647

# %%
df.Composure.count()
# Out:
# 12897

# %%
df['ShortPassing'].std()
# Out:
# 14.740435689517149

# %%
df['Wage'].sum()
# Out:
# 96954000

# %%
df['Value'].min()
# Out:
# 0

# %% [markdown]
# # 5.8

# %%
df[(df.Age < df.Age.mean())&
        (df.Club == 'FC Barcelona')].Wage.mean()
# Out:
# 77454.54545454546

# %%
df[df['Wage'] > df['Wage'].mean()]['SprintSpeed'].mean()
# Out:
# 67.56638061585058

# %%
df[df['Wage'] < df['Wage'].mean()]['SprintSpeed'].mean()
# Out:
# 62.41425430560645

# %%
df[df['Wage'] == df['Wage'].max()]['Position']
# Out:
# 0    RF
# Name: Position, dtype: object

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df.head())
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  HeadingAccuracy  \
# 0  110500000  565000       RF        84         95               70
# 1   77000000  405000       ST        84         94               89
# 2  118500000  290000       LW        79         87               62
# 3   72000000  260000       GK        17         13               21
# 4  102000000  355000      RCM        93         82               55
#
#    ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# ...

# %%
df[df['Nationality'] == 'Brazil']['Penalties'].sum()
# Out:
# 22789

# %%
df[df['HeadingAccuracy'] > 50]['Age'].mean()
# Out:
# 25.58771113179944

# %%
df[(df['Composure'] > (df['Composure'].max()*0.9)) & (df['Reactions'] > (df['Reactions'].max()*0.9))]['Age'].min()
# Out:
# 24

# %%
difference_reaction = df[df['Age'] == df['Age'].max()]['Reactions'].mean() - df[df['Age'] == df['Age'].min()]['Reactions'].mean() 
difference_reaction
# Out:
# 22.642857142857146

# %%
Series_nationality = pd.DataFrame(df[df['Value'] > df['Value'].mean()]['Nationality'])
Series_nationality.describe()
# Out:
#        Nationality
# count         1747
# unique          98
# top          Spain
# freq           211

# %%
gk_wage_reflex = df[(df['Position'] == 'GK') & (df['GKReflexes'] == df['GKReflexes'].max())]['Wage'].mean()
gk_wage_handling = df[(df['Position'] == 'GK') & (df['GKHandling'] == df['GKHandling'].max())]['Wage'].mean()
gk_wage = gk_wage_reflex/gk_wage_handling
gk_wage
# Out:
# 2.765957446808511

# %%
shot_aggression = df[df['Aggression'] == df['Aggression'].max()]['ShotPower'].mean()
shot_non_aggression = df[df['Aggression'] == df['Aggression'].min()]['ShotPower'].mean()
shot_power = shot_aggression/shot_non_aggression
shot_power
# Out:
# 2.076923076923077
